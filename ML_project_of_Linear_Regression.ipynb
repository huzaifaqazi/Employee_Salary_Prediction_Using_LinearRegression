# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler , LabelEncoder , MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression

# %%
data = {
    "Age":[20 , 22 , np.nan , 25 , 21 , 23 , 24 ,np.nan , 22 , 26],
    "Gender":["Male" , "Female" , "Male" , "Female" , np.nan , "Male" , "Female" , "Male" , "Female" , "Male"],
    "City":["Karachi" , "Lahore" , "karachi" , "Islamabad" , "Karachi" , "Lahore" , np.nan , "Karachi" , "Islamabad" , "Karachi"],
    "Salary":[50000 , 60000,55000,np.nan , 52000,58000,62000,54000,56000,np.nan]
}

# %%
df = pd.DataFrame(data)
print("Before Processing")
print(df)
# Out:
# Before Processing
#     Age  Gender       City   Salary
# 0  20.0    Male    Karachi  50000.0
# 1  22.0  Female     Lahore  60000.0
# 2   NaN    Male    karachi  55000.0
# 3  25.0  Female  Islamabad      NaN
# 4  21.0     NaN    Karachi  52000.0
# 5  23.0    Male     Lahore  58000.0
# 6  24.0  Female        NaN  62000.0
# 7   NaN    Male    Karachi  54000.0
# 8  22.0  Female  Islamabad  56000.0
# 9  26.0    Male    Karachi      NaN

# %%
num_imputer = SimpleImputer(strategy="mean")

df[["Age" ,"Salary"]] = num_imputer.fit_transform(df[["Age" , "Salary"]])

cat_imputer = SimpleImputer(strategy="most_frequent")
df[["Gender" , "City"]] = cat_imputer.fit_transform(df[["Gender" , "City"]])

# %%
lebel = LabelEncoder()

df["Gender"] = lebel.fit_transform(df["Gender"])
df = pd.get_dummies(df , columns=["City"])

# %%
scalar = StandardScaler()
df[["Age"]] = scalar.fit_transform(df[["Age"]])

# %%
norm = MinMaxScaler()
df[["Salary"]] = norm.fit_transform(df[["Salary"]] )
print("After Processing")
print(df)
# Out:
# After Processing
#         Age  Gender    Salary  City_Islamabad  City_Karachi  City_Lahore  \
# 0 -1.691908       1  0.000000           False          True        False
# 1 -0.514929       0  0.833333           False         False         True
# 2  0.000000       1  0.416667           False         False        False
# 3  1.250541       0  0.489583            True         False        False
# 4 -1.103419       1  0.166667           False          True        False
# 5  0.073561       1  0.666667           False         False         True
# 6  0.662051       0  1.000000           False          True        False
# 7  0.000000       1  0.333333           False          True        False
# 8 -0.514929       0  0.500000            True         False        False
# 9  1.839031       1  0.489583           False          True        False
#
#    City_karachi
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
# 5         False
# 6         False
# ...

# %%
X = df.drop("Salary"  , axis=1)
Y = df["Salary"]

X_train , X_test , y_train , y_test = train_test_split(X , Y , test_size=0.20 , random_state=42)

model = LinearRegression()

model.fit(X_train , y_train)

prediction = model.predict(X_test)
print("Prediction:" , prediction)
# Out:
# Prediction: [0.25697626 1.22300862]
